# %%
# %%javascript
#
#  function getQueryStringValue (key)
#  {
#      return unescape(window.location.search.replace(new RegExp("^(?:.*[&\\?]" + escape(key).replace(/[\.\+\*]/g, "\\$&") + "(?:\\=([^&]*))?)?.*$", "i"), "$1"));
#  }
# IPython.notebook.kernel.execute("Var1='".concat(getQueryStringValue("filename")).concat("'"));
# //IPython.notebook.kernel.execute("Var2='".concat(getQueryStringValue("Variable2")).concat("'"));
#
# //IPython.notebook.kernel.execute("URL = '" + window.location + "'");

# %%
print(Var1)

# %%
import pandas as pd
import app

# %matplotlib inline

data = []

filename = 'uploads/' + Var1
df = pd.read_csv(filename)

# %%
df.describe()
# Out:
#               cases         deaths
# count  1.830000e+02     183.000000
# mean   1.094520e+06   54815.377049
# std    1.138895e+06   53514.986029
# min    1.000000e+00       0.000000
# 25%    3.695000e+02      17.000000
# 50%    8.104340e+05   44688.000000
# 75%    1.923262e+06  109668.000000
# max    3.910398e+06  142031.000000

# %%
num = input('How many columns would you like to graph?')
# Out:
# How many columns would you like to graph?2

# %%
for i in range(0, int(num)):
    col1 = input('What column would you like to graph? ')
    data.append(col1)
# Out:
# What column would you like to graph? cases
# What column would you like to graph? deaths

# %%
for col1 in data:
    #df[[col1]].plot(kind='line', figsize=(15,10))
    df.plot(kind='line', x=col1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1182: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
for col1 in data:
    #df[[col1]].plot(kind='line', figsize=(15,10))
    df.plot(kind='bar', x=col1)

# %%
for col1 in data:
    #df[[col1]].plot(kind='line', )
    df.hist(figsize=(15,10))

# %%
for col1 in data:
    #df[[col1]].plot(kind='line', figsize=(15,10))
    df.plot(kind='box')

# %%
for col1 in data:
    #df[[col1]].plot(kind='line', figsize=(15,10))
    df.plot(kind='box')

# %%
for col1 in data:
    #df[[col1]].plot(kind='line', figsize=(15,10))
    df.plot(kind='box')
