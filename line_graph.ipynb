# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %matplotlib inline

filename = '/Users/hectorsantiago/PycharmProjects/pearc20_quickviz/csv_files/bfro_OregonReports_geocoded.csv'
df = pd.read_csv(filename)
df.shape
# Out:
# (241, 28)

# %%
df[['county','season','number']].plot(kind='', figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='scatter',x='longitude',y='latitude',color="blue")
plt.show()

# %%
linreg = LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-41961ff0765d> in <module>
# ----> 1 linreg = LinearRegression()
#
# NameError: name 'LinearRegression' is not defined
